# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshatGupta2005/Wipro_Assignments/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Question 1
li = [1,2,3,4,5]
for i in li:
  print(i, end=',')
# Out:
# 1,2,3,4,5,

# %%
#Question 2
li.append(6)
print(li)
# Out:
# [1, 2, 3, 4, 5, 6, 6]

# %%
#Question 3
li[::-1]
# Out:
# [6, 6, 5, 4, 3, 2, 1]

# %%
#Question 4
x = 1
l1 = [1,2,2,1,5,6,1,1,1]
res= 0
for i in l1:
  if i == x:
    res += 1
print(res)
# Out:
# 5

# %%
#Question 5
li_1 = [1,2,3]
li_2 = [4,5,6]
for i in li_1:
  li_2.insert(0,i)
li_2
# Out:
# [3, 2, 1, 4, 5, 6]

# %%
#Question 6
li_2.insert(1,5)

# %%
#Question 7
li_2.pop(3)
# Out:
# 1

# %%
#Question 8
x = 5
for i in range(len(li_2)):
  if li_2[i] == x:
    li_2.pop(i)
    break
li_2
# Out:
# [3, 2, 4, 5, 6]
