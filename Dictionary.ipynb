# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshatGupta2005/Wipro_Assignments/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Question 1
d = {0:10, 1:20}
d[2] = 30
print(d)
# Out:
# {0: 10, 1: 20, 2: 30}

# %%
#Question 2
dic1 = {0:10,1:20}
dic2= {2:30,3:40}
dic3 = {4:50, 5:60}
dic1 = dic1 | dic2 | dic3

# %%
dic1
# Out:
# {0: 10, 1: 20, 2: 30, 3: 40, 4: 50, 5: 60}

# %%
#Question 3
key = int(input("Enter Key to Find : "))
if key in dic1:
  print("Exist")
else:
  print("Does not Exist")
# Out:
# Enter Key to Find : 10
# Does not Exist

# %%
#Question 4
print("Key : ")
for key in dic1:
    print(key)
print('Values : ')
for key in dic1:
  print(dic1[key])
print("Key : Values")
for key in dic1:
  print(f'{key} : {dic1[key]}')
# Out:
# Key :
# 0
# 1
# 2
# 3
# 4
# 5
# Values :
# 10
# 20
# 30
# 40
# 50
# 60
# Key : Values
# 0 : 10
# 1 : 20
# 2 : 30
# 3 : 40
# 4 : 50
# 5 : 60

# %%
#Question 5
dic = {}
for i in range(1,16):
  dic[i] = i * i
print(dic)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %%
#Question 6
res= 0
for key in dic:
  res += dic[key]
print(res)
# Out:
# 1240
